# %%
# %reload_ext autoreload
# %autoreload 2

from cosinecows.dataset import PROCESSED_DATA_DIR, FIGURES_DIR
from cosinecows.plots import generate_plot
import pandas as pd

filename = PROCESSED_DATA_DIR / "cv_run_results.csv"
df = pd.read_csv(filename)
fig = generate_plot(df)

# %%
import matplotlib.pyplot as plt

plt.savefig(FIGURES_DIR / "best-impKnn-outlierPcaIsofor-featSelect-stacking.png")
